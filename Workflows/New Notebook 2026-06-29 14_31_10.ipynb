# %%
# %sql
CREATE OR REPLACE TABLE scd_prac.job_prac.table_list (
  id BIGINT GENERATED ALWAYS AS IDENTITY,
  Name STRING
);

insert into scd_prac.job_prac.table_list (Name)
values ('sales_customers'),
('sales_franchises'),
('sales_suppliers'),
('sales_transactions')
