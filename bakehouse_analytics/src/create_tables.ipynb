# %%
dbutils.widgets.text("table_Name","")
table_Name = dbutils.widgets.get("table_Name")
display(table_Name)

# %%
sql = f"create table if not exists scd_prac.job_prac.{table_Name} select * from samples.bakehouse.{table_Name}"
spark.sql(sql)
