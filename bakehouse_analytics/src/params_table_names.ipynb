# %%
df = spark.sql('''SELECT Name as table_name FROM scd_prac.job_prac.table_list''')

df2 = df.collect()

import json
df_array = json.dumps([i.asDict().get("table_name") for i in df2])
display(df_array)

# %%
dbutils.jobs.taskValues.set(key = "myTables", value = df_array)
